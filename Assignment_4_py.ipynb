# %% [markdown]
# <a href="https://colab.research.google.com/github/Kajallogs/SDL_assignment-4/blob/main/Assignment_4_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as nd

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-93e54a9b-f1d6-49fc-bc8f-627581cf18df" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-93e54a9b-f1d6-49fc-bc8f-627581cf18df">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Table_7_S_1995.csv to Table_7_S_1995 (3).csv

# %%
dataset=pd.read_csv("Table_7_S_1995.csv")

# %%
dataset
# Out:
#   Sl. No. (Col.1)  ... Percentage Male to Total (Col.6) = (Col.3/Col.5) x 100
# 0               1  ...                                              55.31
# 1               2  ...                                              55.18
# 2               3  ...                                              61.24
# 3               4  ...                                              63.75
# 4               5  ...                                              63.40
# 5               6  ...                                              68.46
# 6               7  ...                                              72.29
# 7               8  ...                                              70.20
# 8           Total  ...                                              58.71
#
# [9 rows x 6 columns]

# %%
#load dataset
Y=dataset["Educational Level (Col.2)"]
X=dataset["Total (M+F) (Col.5) = (Col.3+4)"]
plt.scatter(X,Y)
plt.title("Scatter Plot")
plt.ylabel("Fields")
plt.xlabel("Total suicide Count")
plt.show()

# %%
dataset.plot.bar()
plt.title("bar plot")
# Out:
# Text(0.5, 1.0, 'bar plot')

# %%
dataset.boxplot()
plt.title("Box Plot Graph")
# Out:
# Text(0.5, 1.0, 'Box Plot Graph')

# %%
dataset.plot.hist()
plt.title(" Histogram Graph")
# Out:
# Text(0.5, 1.0, ' Histogram Graph')

# %%
plt.plot(dataset["Number of Suicides Deaths - Male (M) (Col.3)"])
plt.title("Number of suicide Deaths(Male)")
# Out:
# Text(0.5, 1.0, 'Number of suicide Deaths(Male)')
